# %%
# %pylab inline
import pylab as plt
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
results = []
with open('lstm_model_wmt_de_00002.npz.txt') as ProgFile:
    results = ProgFile.readlines()

results = [float(results[i]) for i in range(len(results))]
print min(results)
# Out:
# 26.83962056

# %%
plt.plot(results)
plt.xlabel('Iterations')
plt.ylabel('Perplexity')
# Out:
# Text(0,0.5,u'Perplexity')
